# %%
import pandas as pd

df = pd.read_csv('japan_travel4u.csv')

df.sample(10)
# Out:
#       序           出發日期                                            團型名稱  機場  \
# 5    63  2018/07/13(五)                     幸福三都和服體驗.清水寺.東大寺.環球影城螃蟹美食５日  桃園
# 34  274  2018/08/09(四)  FUN暑假~關西三都.海遊館.泡麵DIY體驗.六甲山音樂鐘.雪體驗.小火車.環球影城美食５日  桃園
# 37  277  2018/08/10(五)           五星戀天空.比叡山鐵道.白鬚神社.琵琶湖遊船.米其林景點.空中纜車美食5日  桃園
# 3    59  2018/07/12(四)              FUN暑假～夏戀兩晚京都美山町合掌村.東大寺.黑門市場.環球影城5日  桃園
# 57  379  2018/08/24(五)    漫步阪松~絕美姬路城．和服體驗．大步危遊船．倉敷美觀．小豆島天空步道５日【高松進大阪出】  桃園
# 14  115  2018/07/20(五)      五星南紀勝浦和歌山.採果樂.梅酒DIY體驗.伊勢神宮.海女體驗.?峽遊船海鮮美饌５日  桃園
# 31  270  2018/08/09(四)    【FUN暑假】四都物語雙樂園影城VIP~泡麵杯麵DIY 體驗.海遊館.阿倍野展望台5日遊  桃園
# 13  113  2018/07/20(五)                     幸福三都和服體驗.清水寺.東大寺.環球影城螃蟹美食５日  桃園
# 29  224  2018/08/03(五)      五星南紀勝浦和歌山.採果樂.梅酒DIY體驗.伊勢神宮.海女體驗.?峽遊船海鮮美饌５日  桃園
# 46  328  2018/08/17(五)                     幸福三都和服體驗.清水寺.東大寺.環球影城螃蟹美食５日  桃園
#
#     天數  機位  可售    優惠價     訂金  狀況
# 5    5  25  18  35900  10000 NaN
# 34   5  28  17  39900  10000 NaN
# 37   5  28  27  38900  10000 NaN
# ...

# %%
with open('山富.csv', 'w') as fd:
    for route in df['團型名稱'].unique():
        num = df[df['團型名稱'] == route]['序'].iloc[0]
        fd.write(f"{num} , {route} \n")
